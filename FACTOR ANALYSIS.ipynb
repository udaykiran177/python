# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=list(map(int,input().split()))
y=list(map(int,input().split()))
n=len(x)
x=np.array(x)
y=np.array(y)
a=(n*np.sum(x*y)-np.sum(y))/((n*np.sum(x*x))-(np.sum(x))**2)
b=(np.sum(y)-(n*np.sum(x)))/n
y1=a*x+b
plt.plot(x,y1)
# Out:
# 6 1 5 4 8 18
# 1 3 7 5 4 9
